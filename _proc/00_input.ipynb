# %% [raw]
# ---
# description: The methods in this notebook implement the functionalities for reading
#   the data after exporting them from Learning Locker, to parse the input csd file,
#   and to remove the data which are not necessary for the analysis.
# output-file: input.html
# title: Read and clean the input xAPI dataset
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(foo)
# Out:
# ---
#
# [source](https://github.com/Stocastico/xapi_analysis/blob/main/xapi_analysis/core.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### foo
#
# >      foo ()
